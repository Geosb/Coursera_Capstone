# %% [markdown]
# # Recommending Business ventures that are Most Lucrative Around a College or University Campus in the United States

# %% [markdown]
# # Introduction
#  - Description of the problem and a discussion of the background

# %% [markdown]
# Sometimes intending business owners may have the capital but still do not know what kind of business to  set up in a location that would yield good profit for their investment. A friend of mine had a land close to a university campus, and he was looking for what kind of building or business would be best suited around a university campus that would be lucrative and worth his investment.

# %% [markdown]
# As for the question concerning the viability of a campus environment business investment? The United States alone has over 230 million people. According to the United States Department of Education, there are over 124,000 public and private schools in the United States; over 2,000 postsecondary non-degree career and technical schools; and over 4,000 degree-granting institutions of higher education. Of the higher education institutions, over 1,600 award associate degrees and some 2,400 award bachelor's or higher degrees. Over 400 higher education institutions award research doctorates. As an investor, consider having a few businesses around a few of these institutions, wouldn't that be worth your while? Well, let's find out.

# %% [markdown]
# # Data Description

# %% [markdown]
# Data of a few United States universities campuses would be obtained from data.world in geojson format. The dataset has the geographical coordinates of each campus nested within the geojson file. The geojson  would be cleaned and formatted into a dataframe.

# %% [markdown]
# The Foursquare API would be used to get the common venues around the universities within 1000 mile radius.
# Folium package would used to create maps and place markers on leaflet maps within each campus latitude and longitude location.

# %% [markdown]
# Kmeans will help for clustering and cluster results would be interpreted for recondations
