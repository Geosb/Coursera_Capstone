# %% [markdown]
# ### Scraping Nigeria Rental data

# %% [markdown]
# This project scrapes the number of properties for rents updated on Nigeria Property Centre in Durumi within Federal capital Territory Abuja Nigeria
#
# Note that it could be applied to any other area across nigeria by changing the name to reflect the area required

# %% [markdown]
# ### STAGE ONE: PREPING THE ENVIRONMENT

# %% [markdown]
# Install Packages

# %%
# !pip install datatable
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datatable
#   Downloading datatable-1.0.0-cp37-cp37m-manylinux_2_12_x86_64.whl (96.9 MB)
#      |████████████████████████████████| 96.9 MB 106 kB/s
# Installing collected packages: datatable
# Successfully installed datatable-1.0.0

# %% [markdown]
# Import Packages

# %%
import pandas as pd
import datatable as dt
import time
import datetime
from datetime import datetime
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# Generate date for managing time series data

# %%
current_time = datetime.now()
now = current_time.strftime('%m/%d/%Y')

# %% [markdown]
# Read in our base map for managing the whole process

# %%
df = dt.fread('/content/nga.prop.centre.xlsx')
dfx = df.to_pandas()
dfx.head()
# Out:
#    state                   lga                        path
# 0  abuja                 abaji                 abuja/abaji
# 1  abuja                   apo                   abuja/apo
# 2  abuja      asokoro-district      abuja/asokoro-district
# 3  abuja                 bwari                 abuja/bwari
# 4  abuja  central-area-phase-2  abuja/central-area-phase-2

# %% [markdown]
# Read in our base URL

# %%
url = 'https://nigeriapropertycentre.com/for-rent/'
#url = 'https://nigeriapropertycentre.com/for-rent/abuja?page=1'
#url = 'https://nigeriapropertycentre.com/for-rent/abuja/durumi'
#url = 'https://www.propertypro.ng/property-for-rent/in/abuja/durumi?search=&auto=&type=&bedroom=&min_price=&max_price='

# %% [markdown]
# Create indivual url for scraping stats for each state and local government

# %%
page_no = '?page=1'
spath = dfx.iloc[1,2]
con_path = url + spath + page_no
con_path
# Out:
# 'https://www.propertypro.ng/property-for-rent/in/abuja/durumi?search=&auto=&type=&bedroom=&min_price=&max_price=abuja/apo?page=1'

# %% [markdown]
# ## STAGE TWO: BASIC DATA EXPLORATION

# %% [markdown]
# Read in each dable feom the site into pandas

# %%
dfs = pd.read_html(con_path)

# %% [markdown]
# Select the first table from the above pandas tree

# %%
for dw in dfs:
    if len(dw) == 5:
        table_1 = dw
        break
table_1
# Out:
#             Property Type Count
# 0                   Flats    28
# 1                  Houses    42
# 2                    Land     -
# 3     Commercial Property     1
# 4  Event Centres / Venues     1

# %% [markdown]
# Select the second table from the above pandas tree

# %%
for dw in dfs:
    if len(dw) == 2:
        table_2 = dw
        break
table_2
# Out:
#      Type 1 bed  2 bed  3 bed  4 bed 5 bed
# 0   Flats     3      8     12      2     -
# 1  Houses     -      1      5     17    15

# %% [markdown]
# Select the third table from the above pandas tree

# %%
for dw in dfs:
    if len(dw) == 6:
        table_3 = dw
        break
table_3
# Out:
#           Land Type Count
# 0  Residential Land     -
# 1   Commercial Land     -
# 2   Industrial Land     -
# 3    Mixed-use Land     -
# 4        Other Land     -
# 5          All Land     -

# %% [markdown]
# ## STAGE THREE: DATA MANIPULATION AND CLEANING

# %% [markdown]
# ## Table One(1)

# %% [markdown]
# Rename the table_1 coulumn to reflect rose readable syntax and standard

# %%
b = dfx.iloc[0,0] + "." + dfx.iloc[0,1]
 # c = dfx.iloc[i,0] + "." + b
table_1.rename(columns={'Count':b, 'Property Type':'property.type'}, inplace = True)
table_1
# Out:
#             property.type abuja.abaji
# 0                   Flats          28
# 1                  Houses          42
# 2                    Land           -
# 3     Commercial Property           1
# 4  Event Centres / Venues           1

# %% [markdown]
# ### Merge all local tables from table_1 to form a single table

# %%
dd = table_1.copy() #
#print(dd)
for i in range(1, len(dfx)): #
  spath = dfx.iloc[i,2]
  con_path = url + spath
  dfs = pd.read_html(con_path)
  #print(dfs)
  b = dfx.iloc[i,0] + "." + dfx.iloc[i,1]
  for dw in dfs:
    if len(dw) == 5:
      dw.rename(columns={'Count':b, 'Property Type':'property.type'}, inplace = True)
      
      table = dw
      
      col = table.pop(b)
      #
      cue = i+1
      dd.insert(cue, b, col)
      #break   

col_names = dd.columns 
col_names = [sub.replace('-', '.') for sub in col_names]
dd.columns = col_names
dd
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   if (await self.run_code(code, result,  async_=asy)):
#             property.type abuja.abaji abuja.apo abuja.asokoro.district  \
# 0                   Flats          28        28                     47
# 1                  Houses          42        42                    133
# 2                    Land           -         -                      1
# 3     Commercial Property           1         1                      4
# 4  Event Centres / Venues           1         1                      -
#
#   abuja.bwari abuja.central.area.phase.2 abuja.central.business.district  \
# 0           7                          -                               -
# 1           4                          -                               -
# 2           -                          -                               -
# 3           1                          3                              11
# 4           -                          -                               -
#
#   abuja.cultural.zones abuja.dakibiyu abuja.dakwo  ... rivers.obio.akpor  \
# 0                    1              3           8  ...                 1
# 1                    -              1           8  ...                 -
# 2                    -              -           -  ...                 -
# 3                    -              -           -  ...                 -
# 4                    -              -           -  ...                 -
#
#   rivers.ogba.egbema.ndoni rivers.ogu.bolo rivers.okrika rivers.omuma  \
# 0                        -               -             -            -
# 1                        -               -             -            -
# 2                        -               -             -            -
# 3                        -               -             -            -
# 4                        -               -             -            -
#
#   rivers.opobo.nkoro rivers.oyigbo rivers.port.harcourt rivers.tai  \
# 0                  -             -                   95          -
# 1                  -             -                   55          -
# 2                  -             -                    2          -
# 3                  -             -                   30          -
# 4                  -             -                    2          -
#
#   rivers.rivers
# 0            96
# 1            55
# 2             2
# 3            30
# 4             2
#
# [5 rows x 137 columns]

# %% [markdown]
# Add date column to the dataframe

# %%
my_date = []
for i in range(len(dd)):
  my_date.append(now * 1)
dd.insert(0, 'date', my_date)  
dd
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   if (await self.run_code(code, result,  async_=asy)):
#          date           property.type abuja.abaji abuja.apo  \
# 0  10/28/2022                   Flats          28        28
# 1  10/28/2022                  Houses          42        42
# 2  10/28/2022                    Land           -         -
# 3  10/28/2022     Commercial Property           1         1
# 4  10/28/2022  Event Centres / Venues           1         1
#
#   abuja.asokoro.district abuja.bwari abuja.central.area.phase.2  \
# 0                     47           7                          -
# 1                    133           4                          -
# 2                      1           -                          -
# 3                      4           1                          3
# 4                      -           -                          -
#
#   abuja.central.business.district abuja.cultural.zones abuja.dakibiyu  ...  \
# 0                               -                    1              3  ...
# 1                               -                    -              1  ...
# 2                               -                    -              -  ...
# 3                              11                    -              -  ...
# 4                               -                    -              -  ...
#
#   rivers.obio.akpor rivers.ogba.egbema.ndoni rivers.ogu.bolo rivers.okrika  \
# 0                 1                        -               -             -
# 1                 -                        -               -             -
# 2                 -                        -               -             -
# 3                 -                        -               -             -
# 4                 -                        -               -             -
#
#   rivers.omuma rivers.opobo.nkoro rivers.oyigbo rivers.port.harcourt  \
# 0            -                  -             -                   95
# 1            -                  -             -                   55
# 2            -                  -             -                    2
# 3            -                  -             -                   30
# 4            -                  -             -                    2
#
#   rivers.tai rivers.rivers
# 0          -            96
# 1          -            55
# 2          -             2
# 3          -            30
# 4          -             2
#
# [5 rows x 138 columns]

# %%
dd.to_csv('for_rent.lag.abj.rivers01.csv')

# %% [markdown]
# ## Table Two(2)

# %% [markdown]
# Rename the table_2 coulumn to reflect rose readable syntax and standard

# %%
b = dfx.iloc[0,0] + "." + dfx.iloc[0,1]

col_names = table_2.columns 
col_names = [sub.replace(' ', '.') for sub in col_names]
col_names = [sub.replace('d', 'd.'+b) for sub in col_names]
col_names = [item.lower() for item in col_names]
table_2.columns = col_names
table_2
# Out:
#      type 1.bed.abuja.abaji  2.bed.abuja.abaji  3.bed.abuja.abaji  \
# 0   Flats                 3                  8                 12
# 1  Houses                 -                  1                  5
#
#    4.bed.abuja.abaji 5.bed.abuja.abaji
# 0                  2                 -
# 1                 17                15

# %% [markdown]
# Merge all local tables from table_2 to form a single table

# %%
de = table_2.copy() #
#print(dd)
for i in range(1, len(dfx)): #
  spath = dfx.iloc[i,2]
  con_path = url + spath
  dfs = pd.read_html(con_path)
  #print(dfs)
  b = dfx.iloc[i,0] + "." + dfx.iloc[i,1]
  for dw in dfs:
    if len(dw) == 2:
      col_names = dw.columns 
      col_names = [sub.replace(' ', '.') for sub in col_names]
      col_names = [sub.replace('d', 'd.'+b) for sub in col_names]
      col_names = [sub.replace('-', '.') for sub in col_names]
      col_names = [item.lower() for item in col_names]
      dw.columns = col_names
      table = dw.drop(['type'], axis=1)
      de = pd.concat([de, table], axis=1)
      
de
# Out:
#      type 1.bed.abuja.abaji  2.bed.abuja.abaji  3.bed.abuja.abaji  \
# 0   Flats                 3                  8                 12
# 1  Houses                 -                  1                  5
#
#    4.bed.abuja.abaji 5.bed.abuja.abaji 1.bed.abuja.apo  2.bed.abuja.apo  \
# 0                  2                 -               3                8
# 1                 17                15               -                1
#
#    3.bed.abuja.apo  4.bed.abuja.apo  ... 1.bed.rivers.tai  2.bed.rivers.tai  \
# 0               12                2  ...                -                 -
# 1                5               17  ...                -                 -
#
#    3.bed.rivers.tai  4.bed.rivers.tai  5.bed.rivers.tai  1.bed.rivers.rivers  \
# 0                 -                 -                 -                   10
# 1                 -                 -                 -                    -
#
#   2.bed.rivers.rivers  3.bed.rivers.rivers 4.bed.rivers.rivers  \
# 0                  63                   20                   -
# 1                   5                    9                  30
#
#   5.bed.rivers.rivers
# 0                   -
# 1                   8
#
# [2 rows x 681 columns]

# %% [markdown]
# ### Add date column to the dataframe

# %%
my_date = []
for i in range(len(de)):
  my_date.append(now * 1)
de.insert(0, 'date', my_date)  
de
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   if (await self.run_code(code, result,  async_=asy)):
#          date    type 1.bed.abuja.abaji  2.bed.abuja.abaji  3.bed.abuja.abaji  \
# 0  10/28/2022   Flats                 3                  8                 12
# 1  10/28/2022  Houses                 -                  1                  5
#
#    4.bed.abuja.abaji 5.bed.abuja.abaji 1.bed.abuja.apo  2.bed.abuja.apo  \
# 0                  2                 -               3                8
# 1                 17                15               -                1
#
#    3.bed.abuja.apo  ...  1.bed.rivers.tai 2.bed.rivers.tai  3.bed.rivers.tai  \
# 0               12  ...                 -                -                 -
# 1                5  ...                 -                -                 -
#
#    4.bed.rivers.tai  5.bed.rivers.tai  1.bed.rivers.rivers  \
# 0                 -                 -                   10
# 1                 -                 -                    -
#
#    2.bed.rivers.rivers 3.bed.rivers.rivers  4.bed.rivers.rivers  \
# 0                   63                  20                    -
# 1                    5                   9                   30
#
#   5.bed.rivers.rivers
# 0                   -
# 1                   8
#
# [2 rows x 682 columns]

# %%
de.to_csv('for_rent.lag.abj.rivers02.csv')

# %% [markdown]
# ### Table Three (3)

# %% [markdown]
# Rename the table_3 column to reflect rose syntax and standard

# %%
b = dfx.iloc[0,0] + "." + dfx.iloc[0,1]
table_3.rename(columns={'Count':b, 'Land Type':'land.type'}, inplace = True)
table_3
# Out:
#           land.type abuja.abaji
# 0  Residential Land           -
# 1   Commercial Land           -
# 2   Industrial Land           -
# 3    Mixed-use Land           -
# 4        Other Land           -
# 5          All Land           -

# %% [markdown]
# ### Merge all local tables from table_3 to form a single table

# %%
df = table_3.copy() #
for i in range(1, len(dfx)): #
  spath = dfx.iloc[i,2]
  con_path = url + spath
  dfs = pd.read_html(con_path)
  #print(dfs)
  #b = dfx.iloc[i,1]
  b = dfx.iloc[i,0] + "." + dfx.iloc[i,1]
  for dw in dfs:
    if len(dw) == 6:
      dw.rename(columns={'Count':b, 'Land Type':'land.type'}, inplace = True)
      table = dw
      #
      col = table.pop(b)
      #
      cue = i+1
      df.insert(cue, b, col)
      #break   
col_names = df.columns
col_names = [sub.replace('-', '.') for sub in col_names]
df.columns = col_names
df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   if (await self.run_code(code, result,  async_=asy)):
#           land.type abuja.abaji abuja.apo abuja.asokoro.district abuja.bwari  \
# 0  Residential Land           -         -                      -           -
# 1   Commercial Land           -         -                      -           -
# 2   Industrial Land           -         -                      -           -
# 3    Mixed-use Land           -         -                      -           -
# 4        Other Land           -         -                      1           -
# 5          All Land           -         -                      1           -
#
#   abuja.central.area.phase.2 abuja.central.business.district  \
# 0                          -                               -
# 1                          -                               -
# 2                          -                               -
# 3                          -                               -
# 4                          -                               -
# 5                          -                               -
#
#   abuja.cultural.zones abuja.dakibiyu abuja.dakwo  ... rivers.obio.akpor  \
# 0                    -              -           -  ...                 -
# 1                    -              -           -  ...                 -
# 2                    -              -           -  ...                 -
# 3                    -              -           -  ...                 -
# 4                    -              -           -  ...                 -
# 5                    -              -           -  ...                 -
#
#   rivers.ogba.egbema.ndoni rivers.ogu.bolo rivers.okrika rivers.omuma  \
# 0                        -               -             -            -
# 1                        -               -             -            -
# 2                        -               -             -            -
# 3                        -               -             -            -
# 4                        -               -             -            -
# 5                        -               -             -            -
#
#   rivers.opobo.nkoro rivers.oyigbo rivers.port.harcourt rivers.tai  \
# 0                  -             -                    -          -
# 1                  -             -                    -          -
# 2                  -             -                    -          -
# 3                  -             -                    2          -
# 4                  -             -                    -          -
# 5                  -             -                    2          -
#
#   rivers.rivers
# 0             -
# 1             -
# 2             -
# 3             2
# 4             -
# 5             2
#
# [6 rows x 137 columns]

# %% [markdown]
# Add Date column to the dataframe

# %%
my_date = []
for i in range(len(df)):
  my_date.append(now * 1)
df.insert(0, 'date', my_date)  
df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   if (await self.run_code(code, result,  async_=asy)):
#          date         land.type abuja.abaji abuja.apo abuja.asokoro.district  \
# 0  10/28/2022  Residential Land           -         -                      -
# 1  10/28/2022   Commercial Land           -         -                      -
# 2  10/28/2022   Industrial Land           -         -                      -
# 3  10/28/2022    Mixed-use Land           -         -                      -
# 4  10/28/2022        Other Land           -         -                      1
# 5  10/28/2022          All Land           -         -                      1
#
#   abuja.bwari abuja.central.area.phase.2 abuja.central.business.district  \
# 0           -                          -                               -
# 1           -                          -                               -
# 2           -                          -                               -
# 3           -                          -                               -
# 4           -                          -                               -
# 5           -                          -                               -
#
#   abuja.cultural.zones abuja.dakibiyu  ... rivers.obio.akpor  \
# 0                    -              -  ...                 -
# 1                    -              -  ...                 -
# 2                    -              -  ...                 -
# 3                    -              -  ...                 -
# 4                    -              -  ...                 -
# 5                    -              -  ...                 -
#
#   rivers.ogba.egbema.ndoni rivers.ogu.bolo rivers.okrika rivers.omuma  \
# 0                        -               -             -            -
# 1                        -               -             -            -
# 2                        -               -             -            -
# 3                        -               -             -            -
# 4                        -               -             -            -
# 5                        -               -             -            -
#
#   rivers.opobo.nkoro rivers.oyigbo rivers.port.harcourt rivers.tai  \
# 0                  -             -                    -          -
# 1                  -             -                    -          -
# 2                  -             -                    -          -
# 3                  -             -                    2          -
# 4                  -             -                    -          -
# 5                  -             -                    2          -
#
#   rivers.rivers
# 0             -
# 1             -
# 2             -
# 3             2
# 4             -
# 5             2
#
# [6 rows x 138 columns]

# %% [markdown]
# convert our table to a csv file

# %%
df.to_csv('for_rent.lag.abj.rivers03.csv')
